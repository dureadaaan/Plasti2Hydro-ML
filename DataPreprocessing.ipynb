# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel(r"C:\Users\computer inn\Desktop\G7. Hydrogen-production-from-plastic-waste.xlsx")
df
# Out:
#          PE/PP  Steam/Plastic      Tg (C )  NG/Plastics  P-NH3 (bar)  \
# 0    85.848164       1.530988   983.333333     0.615571          140
# 1    85.848164       1.530988   866.666667     0.615571          140
# 2    85.848164       1.530988  1100.000000     0.615571          140
# 3    85.848164       1.530988   983.333333     0.615571          110
# 4    85.848164       1.530988   983.333333     0.550166          140
# ..         ...            ...          ...          ...          ...
# 923   0.010059       0.995926   983.333333     0.418289           50
# 924   0.010059       0.995926   866.666667     0.418289           50
# 925   0.010059       0.995926  1100.000000     0.418289           50
# 926   0.505072       0.996772   750.000000     0.418644           50
# 927   0.010059       0.995926   750.000000     0.418289           50
#
#      NH3 (kg/h)
# 0    324.165562
# 1    323.830279
# 2    323.712460
# 3    322.830759
# 4    322.782416
# ..          ...
# 923  233.409783
# 924  233.404119
# 925  233.029376
# 926  230.432836
# 927  227.339420
#
# [928 rows x 6 columns]

# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\computer inn\Desktop\G7. Hydrogen-production-from-plastic-waste.xlsx")  

print("===== SHAPE OF DATA =====")
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
print()

print("===== NUMERIC DATA SUMMARY =====")
print(df.describe())
print()


print("===== MODE (Most Frequent Value) =====")
print(df.mode().iloc[0])
print()

print("===== MISSING VALUES =====")
print(df.isnull().sum())
print()

print("===== UNIQUE VALUES PER COLUMN =====")
print(df.nunique())
# Out:
# ===== SHAPE OF DATA =====
# Rows: 928, Columns: 6
#
# ===== NUMERIC DATA SUMMARY =====
#             PE/PP  Steam/Plastic      Tg (C )  NG/Plastics  P-NH3 (bar)  \
# count  928.000000     928.000000   928.000000   928.000000   928.000000
# mean    22.366847       1.780076   930.657328     0.523006    93.448276
# std     36.993805       0.582824   129.707390     0.069967    33.754068
# min      0.010059       0.995926   750.000000     0.418289    50.000000
# 25%      0.505072       1.527086   866.666667     0.483527    50.000000
# 50%      1.956438       1.530988   983.333333     0.548764    80.000000
# 75%     85.848164       2.063505  1100.000000     0.614002   110.000000
# max     85.848165       2.596023  1100.000000     0.615571   140.000000
#
#        NH3 (kg/h)
# count  928.000000
# mean   276.711682
# std     25.280670
# min    227.339420
# 25%    253.591125
# 50%    274.731108
# 75%    301.201201
# max    324.165562
#
# ===== MODE (Most Frequent Value) =====
# PE/PP               1.956438
# Steam/Plastic       1.529685
# Tg (C )          1100.000000
# NG/Plastics         0.484349
# P-NH3 (bar)        50.000000
# NH3 (kg/h)        227.339420
# Name: 0, dtype: float64
#
# ===== MISSING VALUES =====
# PE/PP            0
# Steam/Plastic    0
# Tg (C )          0
# NG/Plastics      0
# P-NH3 (bar)      0
# NH3 (kg/h)       0
# dtype: int64
#
# ===== UNIQUE VALUES PER COLUMN =====
# PE/PP              7
# Steam/Plastic     28
# Tg (C )            4
# NG/Plastics       28
# P-NH3 (bar)        4
# NH3 (kg/h)       928
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel(r"C:\Users\computer inn\Desktop\G7. Hydrogen-production-from-plastic-waste.xlsx") 

# Loop through each numeric column and plot density
for col in df.select_dtypes(include=['number']).columns:
    plt.figure(figsize=(8, 5))
    df[col].plot(kind='density')
    plt.title(f"Density Plot for {col}")
    plt.xlabel(col)
    plt.ylabel("Density")
    plt.grid(True)
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel(r"C:\Users\computer inn\Desktop\G7. Hydrogen-production-from-plastic-waste.xlsx")  

for col in df.select_dtypes(include=['number']).columns:
    plt.figure(figsize=(6, 5))
    df.boxplot(column=col)
    plt.title(f"Box and Whisker Plot for {col}")
    plt.ylabel(col)
    plt.grid(True)
    plt.show()

# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\computer inn\Desktop\G7. Hydrogen-production-from-plastic-waste.xlsx")

# Select only numeric columns for scaling
numeric_cols = df.select_dtypes(include=['number']).columns

# Min-Max scaling
df_normalized = df.copy()
df_normalized[numeric_cols] = (df[numeric_cols] - df[numeric_cols].min()) / (df[numeric_cols].max() - df[numeric_cols].min())

df_normalized.to_excel("normalized_data.xlsx", index=False)

df_normalized
# Out:
#             PE/PP  Steam/Plastic   Tg (C )   NG/Plastics  P-NH3 (bar)  \
# 0    1.000000e+00   3.343935e-01  0.666667  1.000000e+00     1.000000
# 1    1.000000e+00   3.343935e-01  0.333333  1.000000e+00     1.000000
# 2    1.000000e+00   3.343935e-01  1.000000  1.000000e+00     1.000000
# 3    1.000000e+00   3.343935e-01  0.666667  1.000000e+00     0.666667
# 4    1.000000e+00   3.343935e-01  0.666667  6.684723e-01     1.000000
# ..            ...            ...       ...           ...          ...
# 923  0.000000e+00   0.000000e+00  0.666667  0.000000e+00     0.000000
# 924  0.000000e+00   0.000000e+00  0.333333  0.000000e+00     0.000000
# 925  0.000000e+00   0.000000e+00  1.000000  0.000000e+00     0.000000
# 926  5.766812e-03   5.285659e-04  0.000000  1.800560e-03     0.000000
# 927  3.536625e-13   1.859640e-09  0.000000  6.334867e-09     0.000000
#
#      NH3 (kg/h)
# 0      1.000000
# 1      0.996537
# 2      0.995320
# 3      0.986214
# 4      0.985715
# ..          ...
# 923    0.062693
# 924    0.062635
# 925    0.058765
# 926    0.031948
# 927    0.000000
#
# [928 rows x 6 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel(r"C:\Users\computer inn\Desktop\G7. Hydrogen-production-from-plastic-waste.xlsx")

numeric_cols = df.select_dtypes(include=['number']).columns
df_numeric = df[numeric_cols]

# Compute correlation matrix
corr_matrix = df_numeric.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Heatmap (Inputs + Output)")
plt.show()
